# %% [markdown]
# # 🚢 Titanic Machine Learning Model
#
# ## 📋 Overview
#
# Now that the data is clean, I'll build a **machine learning model** to predict passenger survival on the Titanic.
#
# **Goal:** Predict survival for the test dataset (418 passengers)
#
# **Model:** Random Forest Classifier
#
# **Steps:**
# 1. Load cleaned data
# 2. Select features
# 3. Train model
# 4. Evaluate performance
# 5. Make predictions
# 6. Create submission file
